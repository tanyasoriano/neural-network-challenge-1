# %% [markdown]
# # Student Loan Risk with Deep Learning

# %%
# Imports
import pandas as pd
import tensorflow as tf
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report
from pathlib import Path

# %% [markdown]
# ---
#
# ## Prepare the data to be used on a neural network model

# %% [markdown]
# ### Step 1: Read the `student-loans.csv` file into a Pandas DataFrame. Review the DataFrame, looking for columns that could eventually define your features and target variables.

# %%
# Read the csv into a Pandas DataFrame
file_path = "https://static.bc-edx.com/ai/ail-v-1-0/m18/lms/datasets/student-loans.csv"
loans_df = pd.read_csv(file_path)

# Review the DataFrame
loans_df.head()
# Out:
#    payment_history  location_parameter  stem_degree_score  gpa_ranking  \
# 0              7.4                0.70               0.00          1.9
# 1              7.8                0.88               0.00          2.6
# 2              7.8                0.76               0.04          2.3
# 3             11.2                0.28               0.56          1.9
# 4              7.4                0.70               0.00          1.9
#
#    alumni_success  study_major_code  time_to_completion  \
# 0           0.076              11.0                34.0
# 1           0.098              25.0                67.0
# 2           0.092              15.0                54.0
# 3           0.075              17.0                60.0
# 4           0.076              11.0                34.0
#
#    finance_workshop_score  cohort_ranking  total_loan_score  \
# 0                  0.9978            3.51              0.56
# 1                  0.9968            3.20              0.68
# ...

# %%
# Review the data types associated with the columns
loans_df.dtypes
# Out:
# payment_history           float64
# location_parameter        float64
# stem_degree_score         float64
# gpa_ranking               float64
# alumni_success            float64
# study_major_code          float64
# time_to_completion        float64
# finance_workshop_score    float64
# cohort_ranking            float64
# total_loan_score          float64
# financial_aid_score       float64
# credit_ranking              int64
# dtype: object

# %%
# Check the credit_ranking value counts
loans_df["credit_ranking"].value_counts()
# Out:
# credit_ranking
# 1    855
# 0    744
# Name: count, dtype: int64

# %% [markdown]
# ### Step 2: Using the preprocessed data, create the features (`X`) and target (`y`) datasets. The target dataset should be defined by the preprocessed DataFrame column “credit_ranking”. The remaining columns should define the features dataset.

# %%
# Define the target set y using the credit_ranking column
y = loans_df["credit_ranking"].values

# Display a sample of y
y[:5]
# Out:
# array([0, 0, 0, 1, 0])

# %%
# Define features set X by selecting all columns but credit_ranking
X = loans_df.drop(columns="credit_ranking")

# Review the features DataFrame
X[:5]
# Out:
#    payment_history  location_parameter  stem_degree_score  gpa_ranking  \
# 0              7.4                0.70               0.00          1.9
# 1              7.8                0.88               0.00          2.6
# 2              7.8                0.76               0.04          2.3
# 3             11.2                0.28               0.56          1.9
# 4              7.4                0.70               0.00          1.9
#
#    alumni_success  study_major_code  time_to_completion  \
# 0           0.076              11.0                34.0
# 1           0.098              25.0                67.0
# 2           0.092              15.0                54.0
# 3           0.075              17.0                60.0
# 4           0.076              11.0                34.0
#
#    finance_workshop_score  cohort_ranking  total_loan_score  \
# 0                  0.9978            3.51              0.56
# 1                  0.9968            3.20              0.68
# ...

# %% [markdown]
# ### Step 3: Split the features and target sets into training and testing datasets.

# %%
# Split the preprocessed data into a training and testing dataset
# Assign the function a random_state equal to 1
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %% [markdown]
# ### Step 4: Use scikit-learn's `StandardScaler` to scale the features data.

# %%
# Create a StandardScaler instance
X_scaler = StandardScaler()

# Fit the scaler to the features training dataset
X_scaler.fit(X_train)
# Out:
# StandardScaler()

# %%
# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ---
#
# ## Compile and Evaluate a Model Using a Neural Network

# %% [markdown]
# ### Step 1: Create a deep neural network by assigning the number of input features, the number of layers, and the number of neurons on each layer using Tensorflow’s Keras.
#
# > **Hint** You can start with a two-layer deep neural network model that uses the `relu` activation function for both layers.

# %%
# Define the the number of inputs (features) to the model
def create_two_layer_model(input_dim, num_neurons_layer1, num_neurons_layer2):
    model = tf.keras.models.Sequential([
        tf.keras.layers.Dense(num_neurons_layer1, activation='relu', input_shape=(input_dim,)),
        tf.keras.layers.Dense(num_neurons_layer2, activation='relu'),
        tf.keras.layers.Dense(1, activation='sigmoid')
    ])

    return model

# Review the number of features
num_features = X_train_scaled.shape[1]
num_features
# Out:
# 11

# %%
# Define the number of hidden nodes for the first hidden layer
num_hidden_nodes_layer1 = 64
# Review the number hidden nodes in the first layer
print(f"Number of hidden nodes in the first layer: {num_hidden_nodes_layer1}")
# Define the number of hidden nodes for the second hidden layer
num_hidden_nodes_layer2 = 32
# Review the number hidden nodes in the second layer
print(f"Number of hidden nodes in the second layer: {num_hidden_nodes_layer2}")

# Define the number of neurons in the output layer
num_output_neurons = 1
# Review the number of output neurons
print(f"Number of output neurons: {num_output_neurons}")
# Out:
# Number of hidden nodes in the first layer: 64
# Number of hidden nodes in the second layer: 32
# Number of output neurons: 1

# %%
# Create the Sequential model instance

model = create_two_layer_model(num_features, num_hidden_nodes_layer1, num_hidden_nodes_layer2)

# %%
# Display the Sequential model summary
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_6 (Dense)                      │ (None, 64)                  │             768 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_7 (Dense)                      │ (None, 32)                  │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_8 (Dense)                      │ (None, 1)                   │              33 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 8,645 (33.77 KB)
#  Trainable params: 2,881 (11.25 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 5,764 (22.52 KB)

# %% [markdown]
# ### Step 2: Compile and fit the model using the `binary_crossentropy` loss function, the `adam` optimizer, and the `accuracy` evaluation metric.

# %%
# Compile the Sequential model
model.compile(optimizer='adam',
                  loss='binary_crossentropy',
                  metrics=['accuracy'])

# %%
# Fit the model using 50 epochs and the training data
epochs = 50
batch_size = 32
history = model.fit(X_train_scaled, y_train, epochs=epochs, batch_size=batch_size, validation_data=(X_test_scaled, y_test))
# Out:
# Epoch 1/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8717 - loss: 0.3183 - val_accuracy: 0.7250 - val_loss: 0.5679
# Epoch 2/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8740 - loss: 0.3015 - val_accuracy: 0.7325 - val_loss: 0.5730
# Epoch 3/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8710 - loss: 0.3141 - val_accuracy: 0.7250 - val_loss: 0.5722
# Epoch 4/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8748 - loss: 0.3083 - val_accuracy: 0.7350 - val_loss: 0.5838
# Epoch 5/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8742 - loss: 0.3204 - val_accuracy: 0.7325 - val_loss: 0.5758
# Epoch 6/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8883 - loss: 0.2924 - val_accuracy: 0.7300 - val_loss: 0.5747
# Epoch 7/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8877 - loss: 0.2835 - val_accuracy: 0.7375 - val_loss: 0.5811
# Epoch 8/50
# ...

# %% [markdown]
# ### Step 3: Evaluate the model using the test data to determine the model’s loss and accuracy.

# %%
# Evaluate the model loss and accuracy metrics using the evaluate method and the test data

loss, accuracy = model.evaluate(X_test_scaled, y_test)
# Display the model loss and accuracy results
print(f"Test Loss: {loss:.4f}")
print(f"Test Accuracy: {accuracy:.4f}")
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7609 - loss: 0.6709
# Test Loss: 0.6859
# Test Accuracy: 0.7475

# %% [markdown]
# ### Step 4: Save and export your model to a keras file, and name the file `student_loans.keras`.

# %%
# Set the model's file path
model_file_path = "student_loans.keras"
# Export your model to a keras file
model.save(model_file_path)
print(f"Model saved to {model_file_path}")
# Out:
# Model saved to student_loans.keras

# %% [markdown]
# ---
# ## Predict Loan Repayment Success by Using your Neural Network Model

# %% [markdown]
# ### Step 1: Reload your saved model.

# %%
# Set the model's file path
model_file_path = "student_loans.keras"
# Load the model to a new object
loaded_model = tf.keras.models.load_model(model_file_path)

# %% [markdown]
# ### Step 2: Make predictions on the testing data and save the predictions to a DataFrame.

# %%
# Make predictions with the test data
predictions = loaded_model.predict(X_test_scaled)

# Create a DataFrame to store the predictions
predictions_df = pd.DataFrame({'Actual': y_test, 'Predicted': predictions.flatten()})

# Display a sample of the predictions
print(type(predictions))
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# <class 'numpy.ndarray'>

# %%
# Save the predictions to a DataFrame and round the predictions to binary results
predictions_df['Predicted'] = predictions_df['Predicted'].apply(lambda x: round(x))
predictions_df.head()
# Out:
#    Actual  Predicted
# 0       0          0
# 1       1          0
# 2       1          1
# 3       1          1
# 4       1          1

# %% [markdown]
# ### Step 4: Display a classification report with the y test data and predictions

# %%
# Print the classification report with the y test data and predictions
report = classification_report(y_test, predictions_df['Predicted'])
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.74      0.72      0.73       188
#            1       0.76      0.77      0.76       212
#
#     accuracy                           0.75       400
#    macro avg       0.75      0.75      0.75       400
# weighted avg       0.75      0.75      0.75       400

# %% [markdown]
# ---
# ## Discuss creating a recommendation system for student loans

# %% [markdown]
# Briefly answer the following questions in the space provided:
#
# 1. Describe the data that you would need to collect to build a recommendation system to recommend student loan options for students. Explain why this data would be relevant and appropriate.
#
# A sound and robust student loan recommendation system requires comprehensive historical and current data:
#
# Student Information: Demographics, academic details such as school, grade average, prospective graduation date, financial background information to include parent credit score and household income.
#
# Loan Details: Loan terms, interest rates, fees and other requirements.
#
# Due to the sensitive nature of this financial data, privacy and security measures are also essential.
#
#
#
# 2. Based on the data you chose to use in this recommendation system, would your model be using collaborative filtering, content-based filtering, or context-based filtering? Justify why the data you selected would be suitable for your choice of filtering method.
#
# This model would primarily utilize a content-based filtering approach, with some elements of context-based filtering. The model would attempt to match the student with the right type of loan based on student eligibility data and loan features, but would also give weight to information like specific school or university loan policies, and student academic performance as an example.
#
#
#
# 3. Describe two real-world challenges that you would take into consideration while building a recommendation system for student loans. Explain why these challenges would be of concern for a student loan recommendation system.
#
# Two real-world challenges to consider when building a student loan recommendation system are bias in the data and the potential for exploitation by predatory lenders. A careful review of the data preprocessing, feature engineering, and model evaluation techniques are vital to ensure bias is not inadvertently introduced to the model. For example, if the historical data is only representing students from upper socio-economic backgrounds this could discrimate against students from certain geographical areas in an unfair way. The second challenge to consider is the model being exploited by predatory lenders which is a real concern facing students today. A predatory lender could use the model to highlight the most vulnerable of students.
